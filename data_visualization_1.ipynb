# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
titanic = sns.load_dataset("titanic")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic['age'] = titanic['age'].fillna(titanic['age'].mean())

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.title("Count vs Age")
sns.histplot(data=titanic, x='age')
plt.subplot(1, 2, 2)
plt.title("Count vs Fare")
sns.histplot(data=titanic, x="fare", bins=20)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(titanic['fare'], bins=20, kde=True, color='skyblue', edgecolor='black')
plt.title('Distribution of Ticket Prices (Fare)')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.show()

# %%
titanic = sns.load_dataset('titanic')

plt.subplot(2,2,1)
sns.histplot(data=titanic, x='age', hue='sex', multiple="dodge")

plt.subplot(2,2,2)
sns.histplot(data=titanic, x='age', hue='survived', multiple="dodge", shrink=.8)

plt.subplot(2,2,3)
sns.histplot(data=titanic, x='fare', hue='sex', multiple="dodge", binwidth=20, bins=10)

plt.subplot(2,2,4)
sns.histplot(data=titanic, x='fare', hue='survived', multiple="dodge", binwidth=20, bins=10)

plt.tight_layout()

plt.show()
